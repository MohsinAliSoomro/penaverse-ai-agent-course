# %%
# Assignment of brothers
name = "Rehan"
teachers_list = ["Salman","Mazhar"]
teachers_list.append(name)

print(id(name))
print(id(teachers_list[2]))
# Out:
# 4615288896
# 4615288896

# %%
# Assignment 2
string ="Rehan"
# print(dir(string))

# capitalize
print("capitalize: ",string.capitalize())
# casefold
print("casefold: ",string.casefold())
# center
print("center: ",string.center(10))
# count
print("count: ",string.count("a"))
# encode
print("encode: ",string.encode())
# endswith
print("endswith: ",string.endswith("n"))
# expandtabs
print("expandtabs: ",string.expandtabs())
# find
print("find: ",string.find("n"))
# format
print("format: ",string.format())
# format_map
print("format_map: ",string.format_map("Rehan"))
# index
print("index: ",string.index("n"))
# isalnum
print("isalnum: ",string.isalnum())
# isalpha
print("isalpha: ",string.isalpha())
# isascii
print("isascii: ",string.isascii())
# isdecimal
print("isdecimal: ",string.isdecimal())
# isdigit
print("isdigit: ",string.isdigit())
# isidentifier
print("isidentifier: ",string.isidentifier())
# islower
print("islower: ",string.islower())
# isnumeric
print("isnumeric: ",string.isnumeric())
# isprintable
print("isprintable: ",string.isprintable())
# isspace
print("isspace: ",string.isspace())
# istitle
print("istitle: ",string.istitle())
# isupper
print("isupper: ",string.isupper())
# join
print("join: ",string.join("Rehan"))
# ljust
print("ljust: ",string.ljust(10))
# lstrip
print("lstrip: ",string.lstrip())
# maketrans
# print("maketrans: ",string.maketrans("Rehan"))
# partition
print("partition: ",string.partition("Rehan"))
# replace
# print("replace: ",string.replace("Rehan"))
# removeprefix
print("removeprefix: ",string.removeprefix("Rehan"))
# removesuffix
print("removesuffix: ",string.removesuffix("Rehan"))
# rfind
print("rfind: ",string.rfind("Rehan"))
# replace
# print("replace: ",string.replace("Rehan"))
# rindex
print("rindex: ",string.rindex("Rehan"))
# rjust
print("rjust: ",string.rjust(10))
# rpartition
print("rpartition: ",string.rpartition("Rehan"))
# rsplit
print("rsplit: ",string.rsplit("Rehan"))
# rstrip
print("rstrip: ",string.rstrip())
# split
print("split: ",string.split("Rehan"))
# splitlines
print("splitlines: ",string.splitlines())
# startswith
print("startswith: ",string.startswith("Rehan"))
# strip
print("strip: ",string.strip())
# swapcase
print("swapcase: ",string.swapcase())
# title
print("title: ",string.title())
# translate
print("translate: ",string.translate("Rehan"))
# upper
print("upper: ",string.upper())
# zfill
print("zfill: ",string.zfill(10))
# Out:
# capitalize:  Rehan
# casefold:  rehan
# center:    Rehan
# count:  1
# encode:  b'Rehan'
# endswith:  True
# expandtabs:  Rehan
# find:  4
# format:  Rehan
# format_map:  Rehan
# index:  4
# isalnum:  True
# isalpha:  True
# isascii:  True
# isdecimal:  False
# isdigit:  False
# isidentifier:  True
# islower:  False
# isnumeric:  False
# isprintable:  True
# isspace:  False
# istitle:  True
# isupper:  False
# join:  RRehaneRehanhRehanaRehann
# ljust:  Rehan
# lstrip:  Rehan
# partition:  ('', 'Rehan', '')
# removeprefix:
# removesuffix:
# rfind:  0
# rindex:  0
# rjust:       Rehan
# rpartition:  ('', 'Rehan', '')
# rsplit:  ['', '']
# rstrip:  Rehan
# split:  ['', '']
# splitlines:  ['Rehan']
# startswith:  True
# strip:  Rehan
# swapcase:  rEHAN
# title:  Rehan
# translate:  Rehan
# upper:  REHAN
# zfill:  00000Rehan
